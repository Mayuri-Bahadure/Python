# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import requests

# %%
Product_name = []
Prices = []
Description = []
Reviews = []

for i in range(2,10):
    URL = "https://www.flipkart.com/search?q=camera+digital+camera&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=camera+digital+camera&requestId=7397076b-08fa-4b3f-a100-87ed229d29ec&page="+str(i)
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, "html.parser")
    np = soup.find("a", class_ ="_1LKTO3").get("href")
    cnp ="https://www.flipcart.com"+np
    
    
    box = soup.find("div",class_ ="_1YokD2 _3Mn1Gg")

    names = box.find_all("div",class_ ="_4rR01T")
    for i in names:
        name = i.text
        Product_name.append(name)
    
    prices = box.find_all("div", class_ = "_30jeq3 _1_WHN1")
    for i in prices:
        name = i.text
        Prices.append(name)
        
    desc = box.find_all("ul", class_ = "_1xgFaf")
    for i in desc:
        name = i.text
        Description.append(name)
        
    reviews = box.find_all("div",class_ = "_3LWZlK")
    for i in reviews:
        name = i.text
        Reviews.append(name)
        
max_length = max(len(Product_name), len(Prices), len(Description), len(Reviews))
Product_name += [None] * (max_length - len(Product_name))
Prices += [None] * (max_length - len(Prices))
Description += [None] * (max_length - len(Description))
Reviews += [None] * (max_length - len(Reviews))

df = pd.DataFrame({"Product Name":Product_name, "Prices":Prices, "Description":Description, "Reviews":Reviews})
print(df)

df.to_csv("C:/Users/Hrushi/MayuriPython/Flipcart_Web_Scrapping1.csv")
# Out:
#                                           Product Name   Prices  \
# 0    Bzrqx Gift Toy Baby Camera Gift Kids Children ...     ₹899
# 1    Bzrqx Gift Toy Baby Camera HD 8MP Video Digita...     ₹899
# 2    Canon R100 Mirrorless Camera RF-S 18-45mm f/4....  ₹47,990
# 3                                  Canon PowerShot V10  ₹29,990
# 4    Toyvala Unique Digital Camera For Kids With SD...     ₹999
# ..                                                 ...      ...
# 115  AVOIHS Gift toys Gift Kids Children HD 2 Inch ...     ₹899
# 116  Bzrqx Gift Toy Baby Camera Gift Kids Children ...     ₹899
# 117  AVOIHS Gift toys Gift Kids Children HD 2 Inch ...     ₹899
# 118  AVOIHS Gift toys Gift Kids Children Digital Ca...     ₹899
# 119  AVOIHS Gift toys 1080P Digital Camera Kids Gif...     ₹899
#
#                                            Description Reviews
# 0    Effective Pixels: 8 MPHD7 Days Replacement War...     2.7
# 1    Effective Pixels: 8 MPHD7 Days Replacement War...     4.5
# ...

# %%
df
# Out:
#                                           Product Name   Prices  \
# 0    Bzrqx Gift Toy Baby Camera Gift Kids Children ...     ₹899
# 1    Bzrqx Gift Toy Baby Camera HD 8MP Video Digita...     ₹899
# 2    Canon R100 Mirrorless Camera RF-S 18-45mm f/4....  ₹47,990
# 3                                  Canon PowerShot V10  ₹29,990
# 4    Toyvala Unique Digital Camera For Kids With SD...     ₹999
# ..                                                 ...      ...
# 115  AVOIHS Gift toys Gift Kids Children HD 2 Inch ...     ₹899
# 116  Bzrqx Gift Toy Baby Camera Gift Kids Children ...     ₹899
# 117  AVOIHS Gift toys Gift Kids Children HD 2 Inch ...     ₹899
# 118  AVOIHS Gift toys Gift Kids Children Digital Ca...     ₹899
# 119  AVOIHS Gift toys 1080P Digital Camera Kids Gif...     ₹899
#
#                                            Description Reviews
# 0    Effective Pixels: 8 MPHD7 Days Replacement War...     2.7
# 1    Effective Pixels: 8 MPHD7 Days Replacement War...     4.5
# ...

# %% [markdown]
# ## DESCRIPTION
# ### Step:1 Import Necessary Libraries
# first I import Pandas, numpy, BeutifulSoup and Request libraries.
#
# Function Of Libraries:
# 1) Numpy: NumPy provides support for creating and manipulating arrays, which are more efficient than Python lists for numerical operations.
# 2) Pandas: Pandas provides the DataFrame and Series data structures, which are designed for efficient data manipulation and analysis.
# 3) BeutifulSoup: Beautiful Soup is used for parsing HTML and XML documents, making it easy to extract data from web pages.
# 4) Requests:  Requests is used to send HTTP requests to web servers and receive responses.
#
# ### Step:2 Get URL Access
# In this step get url from flipcart website of digital cameras page. But here i am get html data for only one page but want to scrape more data so here i create for loop and at the end of url i add string (+str(i)) so i can scrape data of more than 1 page. for this step use request library.
#
# ### Step:3 Collect Information
# in this step parse information about title, price, reviews and description using html code. to collect information create for loop for every column using beutiful.soup library.
#
# ### Srep:4 Creating DataFrame
# in this step create dataframe for to gather all information about particular column and save it to the csv. but during creating dataframe i face problem i have 127 count for 2 arrays and 128 count for another 2 arrays. so solve this problem i add max-lenght array to mantain the lenght.
